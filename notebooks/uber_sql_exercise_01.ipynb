# %%
# Placeholder: use KaggleHub to fetch datasets for this notebook
import kagglehub

# %% [markdown]
# # Uber SQL Database - Setup Notebook
#
# This notebook is the first real exercise notebook scaffold and currently only sets up dataset access.
# No exercises are included yet.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rockyt07/uber-sql-database")

print("Path to dataset files:", path)
