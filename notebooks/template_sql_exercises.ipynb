# %%
import kagglehub
from pathlib import Path
import shutil

# Download latest version of dataset
path = kagglehub.dataset_download("rockyt07/uber-sql-database")

# Install SQL magic
# %pip -q install ipython-sql

# Load SQL extension and configure
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# Copy database to workspace and connect
cache_db = Path(path) / "rideshare.db"
local_db = Path("/workspaces/aButtTonOfSqlQuestions/datasets/sqlite/uber_rideshare.db")
local_db.parent.mkdir(parents=True, exist_ok=True)
shutil.copy2(cache_db, local_db)

# %sql sqlite:////workspaces/aButtTonOfSqlQuestions/datasets/sqlite/uber_rideshare.db

print("✓ Setup complete! Database ready.")

# %% [markdown]
# # Uber SQL Database - Unit 4 Practice
#
# ## ⚠️ IMPORTANT: Run the setup code cell above FIRST
#
# Before attempting any exercises, execute the code cell above by clicking the play button or pressing Shift+Enter. This will:
# 1. Download the Uber rideshare dataset
# 2. Install the SQL magic extension (ipython-sql)
# 3. Connect to the SQLite database
# 4. Prepare the environment for SQL queries
#
# Once you see "✓ Setup complete! Database ready." message, you can start writing your SQL answers in the exercise cells below.

# %% [markdown]
# ## Exercise 1
# Write a query to list all rows from a table named students.

# %%
# %%sql
# -- Exercise 1 answer here

# %% [markdown]
# ## Exercise 2
# Select only the columns student_id and name from students.

# %%
# %%sql
# -- Exercise 2 answer here

# %% [markdown]
# ## Exercise 3
# Filter students to only those in year_group 12.

# %%
# %%sql
# -- Exercise 3 answer here

# %% [markdown]
# ## Exercise 4
# Count how many students are in each year_group.

# %%
# %%sql
# -- Exercise 4 answer here

# %% [markdown]
# ## Exercise 5
# List students ordered alphabetically by surname.

# %%
# %%sql
# -- Exercise 5 answer here

# %% [markdown]
# ## Exercise 6
# Find the top 5 highest-scoring students from an exam_results table.

# %%
# %%sql
# -- Exercise 6 answer here

# %% [markdown]
# ## Exercise 7
# Use GROUP BY to calculate average score per subject.

# %%
# %%sql
# -- Exercise 7 answer here

# %% [markdown]
# ## Exercise 8
# Join students and exam_results to show name, subject, and score.

# %%
# %%sql
# -- Exercise 8 answer here

# %% [markdown]
# ## Exercise 9
# Show students who have no exam_results using a LEFT JOIN.

# %%
# %%sql
# -- Exercise 9 answer here

# %% [markdown]
# ## Exercise 10
# Write a query using a subquery to find students above the overall average score.

# %%
# %%sql
# -- Exercise 10 answer here
